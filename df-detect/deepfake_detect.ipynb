# %%
import tensorflow as tf
from train import main

# %%
main()
# Out:
# ****************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************FOUND CPU AT:  /physical_device:CPU:0
# ['/physical_device:GPU:0']
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d (ConvLSTM2D)    (None, None, 111, 111, 32 40448
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, None, 55, 55, 32)  73856
# _________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)  (None, None, 27, 27, 32)  73856
# _________________________________________________________________
# conv_lst_m2d_3 (ConvLSTM2D)  (None, 13, 13, 32)        73856
# _________________________________________________________________
# conv2d (Conv2D)              (None, 6, 6, 16)          4624
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 2, 2, 16)          2320
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 65
# =================================================================
# Total params: 269,025
# Trainable params: 269,025
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
#     100/Unknown - 410s 4s/step - loss: 0.2151 - binary_accuracy: 1.0000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-263240bbee7e> in <module>
# ----> 1 main()
#
# ~/deepfake-proj/df-detect/train.py in main()
#     154                         callbacks=callbacks,
#     155                         validation_data=val_ds,
# --> 156                         validation_steps=10,
#     157                         )
#     158   else:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      60   def _method_wrapper(self, *args, **kwargs):
#      61     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 62       return method(self, *args, **kwargs)
#      63
#      64     return dc.run_distribute_coordinator(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     793           epoch_logs.update(val_logs)
#     794
# --> 795         callbacks.on_epoch_end(epoch, epoch_logs)
#     796         if self.stop_training:
#     797           break
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     347     logs = self._process_logs(logs)
#     348     for callback in self.callbacks:
# --> 349       callback.on_epoch_end(epoch, logs)
#     350
#     351   def on_train_batch_begin(self, batch, logs=None):
#
# ~/deepfake-proj/df-detect/train.py in on_epoch_end(self, epoch, logs)
#      27   def on_epoch_end(self, epoch, logs=None):
#      28     print('\nLearning rate for epoch {} is {}'.format(epoch + 1,
# ---> 29                                                       model.optimizer.lr.numpy()))
#      30
#      31 def decay(epoch):
#
# NameError: name 'model' is not defined

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.ylabel("Acc")
plt.xlabel("Training Steps")
plt.ylim([0,2])
plt.plot(batch_stats_callback.batch_acc)

# %%
history.
